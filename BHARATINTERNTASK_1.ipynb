# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-581224-1694611532/blob/main/BHARATINTERNTASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATA SCIENCEINTERNSHIP @BHARAT INTERN**

# %% [markdown]
# # NAME:DUNNA JAYANTH VARMA

# %% [markdown]
# # TASK1:STOCK PREDICTION (TO PREDICT THE STOCK PRICE OFA COMPANY USING LSTM

# %% [markdown]
# # **STEPS TAKEN:**
# ##1.IMPORTING LIBRARIES
# ##2.GATHERING INSIGHTS
# ##3.PRE-PROCESSING THE DATA
# ##4.CREATING LSTM MODEL
# ##5.VISUALIZING ACTUAL VS PREDICTED DATA
# ##6.PREDICTING UPCOMING 15 DAYS

# %% [markdown]
# ##STEP1:IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt#data preprocessing
import seaborn as sns#data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')#ignore warnings

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout,LSTM,Bidirectional

# %%
df=pd.read_csv('Task_1_Stocks_dataset.csv')

# %%
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ## STEP2:GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# There are no null values in the datset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

# %%
ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

# %% [markdown]
# # STEP-3:DATA PREPROCESSING

# %%
MMS=MinMaxScaler()
df[df.columns]=MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# # STEP-4 CREATING LSTM MODEL

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 93ms/step - loss: 0.0051 - mean_absolute_error: 0.0496 - val_loss: 0.0084 - val_mean_absolute_error: 0.0711
# Epoch 2/100
# 28/28 [==============================] - 2s 56ms/step - loss: 5.7510e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0060 - val_mean_absolute_error: 0.0624
# Epoch 3/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.0316e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0035 - val_mean_absolute_error: 0.0449
# Epoch 4/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.8837e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0034 - val_mean_absolute_error: 0.0444
# Epoch 5/100
# 28/28 [==============================] - 2s 65ms/step - loss: 3.8130e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0035 - val_mean_absolute_error: 0.0451
# Epoch 6/100
# 28/28 [==============================] - 2s 89ms/step - loss: 4.0371e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0039 - val_mean_absolute_error: 0.0485
# Epoch 7/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.5820e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0032 - val_mean_absolute_error: 0.0432
# Epoch 8/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.0213e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0048 - val_mean_absolute_error: 0.0550
# Epoch 9/100
# 28/28 [==============================] - 2s 76ms/step - loss: 3.7677e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0043 - val_mean_absolute_error: 0.0520
# Epoch 10/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.3240e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0041 - val_mean_absolute_error: 0.0503
# Epoch 11/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.2095e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0045 - val_mean_absolute_error: 0.0542
# Epoch 12/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.2429e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0037 - val_mean_absolute_error: 0.0486
# Epoch 13/100
# 28/28 [==============================] - 3s 90ms/step - loss: 3.6089e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 14/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.1581e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0038 - val_mean_absolute_error: 0.0488
# Epoch 15/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.1753e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 16/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.0874e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 17/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.9105e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0029 - val_mean_absolute_error: 0.0409
# Epoch 18/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.0469e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0072 - val_mean_absolute_error: 0.0702
# Epoch 19/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.9186e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0044 - val_mean_absolute_error: 0.0519
# Epoch 20/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.7102e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0059 - val_mean_absolute_error: 0.0604
# Epoch 21/100
# 28/28 [==============================] - 2s 84ms/step - loss: 2.8215e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0046 - val_mean_absolute_error: 0.0525
# Epoch 22/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.8453e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0051 - val_mean_absolute_error: 0.0549
# Epoch 23/100
# 28/28 [==============================] - 1s 54ms/step - loss: 2.6525e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0027 - val_mean_absolute_error: 0.0376
# Epoch 24/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.8362e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0029 - val_mean_absolute_error: 0.0389
# Epoch 25/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.7124e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 26/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.7237e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0053 - val_mean_absolute_error: 0.0571
# Epoch 27/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.6342e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0049 - val_mean_absolute_error: 0.0548
# Epoch 28/100
# 28/28 [==============================] - 2s 90ms/step - loss: 2.5508e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0043 - val_mean_absolute_error: 0.0496
# Epoch 29/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.3944e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0071 - val_mean_absolute_error: 0.0638
# Epoch 30/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.4616e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0064 - val_mean_absolute_error: 0.0609
# Epoch 31/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3522e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0074 - val_mean_absolute_error: 0.0676
# Epoch 32/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.4753e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0085 - val_mean_absolute_error: 0.0753
# Epoch 33/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.5051e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0042 - val_mean_absolute_error: 0.0470
# Epoch 34/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2473e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0052 - val_mean_absolute_error: 0.0538
# Epoch 35/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.4304e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0030 - val_mean_absolute_error: 0.0383
# Epoch 36/100
# 28/28 [==============================] - 2s 88ms/step - loss: 2.3168e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0042 - val_mean_absolute_error: 0.0479
# Epoch 37/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.7015e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0051 - val_mean_absolute_error: 0.0563
# Epoch 38/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.1265e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0035 - val_mean_absolute_error: 0.0436
# Epoch 39/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.1713e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0020 - val_mean_absolute_error: 0.0316
# Epoch 40/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.2579e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0045 - val_mean_absolute_error: 0.0507
# Epoch 41/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.1509e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0062 - val_mean_absolute_error: 0.0624
# Epoch 42/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.5391e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0016 - val_mean_absolute_error: 0.0285
# Epoch 43/100
# 28/28 [==============================] - 2s 82ms/step - loss: 2.2330e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0027 - val_mean_absolute_error: 0.0384
# Epoch 44/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.8934e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0029 - val_mean_absolute_error: 0.0397
# Epoch 45/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.0495e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0048 - val_mean_absolute_error: 0.0553
# Epoch 46/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.1216e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0024 - val_mean_absolute_error: 0.0352
# Epoch 47/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2672e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268
# Epoch 48/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.3631e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0027 - val_mean_absolute_error: 0.0386
# Epoch 49/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.0388e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0045 - val_mean_absolute_error: 0.0536
# Epoch 50/100
# 28/28 [==============================] - 4s 130ms/step - loss: 1.8758e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0031 - val_mean_absolute_error: 0.0430
# Epoch 51/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.9717e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0027 - val_mean_absolute_error: 0.0382
# Epoch 52/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8360e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0023 - val_mean_absolute_error: 0.0345
# Epoch 53/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.0983e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0026 - val_mean_absolute_error: 0.0378
# Epoch 54/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.7058e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0027 - val_mean_absolute_error: 0.0395
# Epoch 55/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.7395e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 56/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.6995e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0039 - val_mean_absolute_error: 0.0494
# Epoch 57/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7819e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0025 - val_mean_absolute_error: 0.0375
# Epoch 58/100
# 28/28 [==============================] - 3s 90ms/step - loss: 1.7695e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0043 - val_mean_absolute_error: 0.0525
# Epoch 59/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8489e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 60/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7821e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0016 - val_mean_absolute_error: 0.0289
# Epoch 61/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.8319e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0020 - val_mean_absolute_error: 0.0319
# Epoch 62/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7083e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0028 - val_mean_absolute_error: 0.0394
# Epoch 63/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.6319e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0035 - val_mean_absolute_error: 0.0453
# Epoch 64/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6443e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 65/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.6008e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0032 - val_mean_absolute_error: 0.0451
# Epoch 66/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.5901e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0037 - val_mean_absolute_error: 0.0478
# Epoch 67/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.6682e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 68/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.7314e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0025 - val_mean_absolute_error: 0.0373
# Epoch 69/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0028 - val_mean_absolute_error: 0.0405
# Epoch 70/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.4800e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0305
# Epoch 71/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4560e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0022 - val_mean_absolute_error: 0.0361
# Epoch 72/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.4642e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0292
# Epoch 73/100
# 28/28 [==============================] - 3s 94ms/step - loss: 1.4857e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 74/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.4319e-04 - mean_absolute_error: 0.0086 - val_loss: 8.7712e-04 - val_mean_absolute_error: 0.0216
# Epoch 75/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.5505e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0010 - val_mean_absolute_error: 0.0235
# Epoch 76/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.3848e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 77/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.5694e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0031 - val_mean_absolute_error: 0.0459
# Epoch 78/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4925e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 79/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3126e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 80/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.4876e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0298
# Epoch 81/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.4237e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 82/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.5202e-04 - mean_absolute_error: 0.0088 - val_loss: 8.1129e-04 - val_mean_absolute_error: 0.0209
# Epoch 83/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4261e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 84/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.3804e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0025 - val_mean_absolute_error: 0.0383
# Epoch 85/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5671e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0023 - val_mean_absolute_error: 0.0380
# Epoch 86/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3318e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0029 - val_mean_absolute_error: 0.0435
# Epoch 87/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2928e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0018 - val_mean_absolute_error: 0.0327
# Epoch 88/100
# 28/28 [==============================] - 2s 90ms/step - loss: 1.2582e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0023 - val_mean_absolute_error: 0.0380
# Epoch 89/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.1871e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0022 - val_mean_absolute_error: 0.0379
# Epoch 90/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.5463e-04 - mean_absolute_error: 0.0090 - val_loss: 7.8744e-04 - val_mean_absolute_error: 0.0206
# Epoch 91/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.5372e-04 - mean_absolute_error: 0.0090 - val_loss: 6.8094e-04 - val_mean_absolute_error: 0.0190
# Epoch 92/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3870e-04 - mean_absolute_error: 0.0086 - val_loss: 9.0650e-04 - val_mean_absolute_error: 0.0226
# Epoch 93/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.4473e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0347
# Epoch 94/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3529e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 95/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.0819e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0023 - val_mean_absolute_error: 0.0389
# Epoch 96/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.1469e-04 - mean_absolute_error: 0.0076 - val_loss: 9.1846e-04 - val_mean_absolute_error: 0.0223
# Epoch 97/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1887e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 98/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2142e-04 - mean_absolute_error: 0.0078 - val_loss: 7.9945e-04 - val_mean_absolute_error: 0.0205
# Epoch 99/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3063e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 100/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1420e-04 - mean_absolute_error: 0.0077 - val_loss: 8.0465e-04 - val_mean_absolute_error: 0.0207

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 15ms/step
# array([[0.40993407, 0.41445887],
#        [0.40963078, 0.4139188 ],
#        [0.40520948, 0.4093761 ],
#        [0.40808418, 0.41249636],
#        [0.41172844, 0.41632932]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1430.985 , 1436.3932],
#        [1430.4227, 1435.3923],
#        [1422.226 , 1426.9731],
#        [1427.5554, 1432.756 ],
#        [1434.3116, 1439.8599]], dtype=float32)

# %% [markdown]
# #STEP-5: VISUALIZING ACTUAL VS PREDICTDD DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                     open         close  open_predicted  close_predicted
# date
# 2020-05-27  2.628139e+06  2.628408e+06     1430.984985      1436.393188
# 2020-05-28  2.590338e+06  2.626351e+06     1430.422729      1435.392334
# 2020-05-29  2.627564e+06  2.648943e+06     1422.225952      1426.973145
# 2020-06-01  2.630253e+06  2.654318e+06     1427.555420      1432.755981
# 2020-06-02  2.652796e+06  2.668032e+06     1434.311646      1439.859863

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # STEP-6 PREDICTING UPCOMING 10DAYS

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                     open         close  open_predicted  close_predicted
# 2021-06-09  4.634544e+06  4.618080e+06     2391.032471      2408.307861
# 2021-06-10  4.624366e+06  4.674050e+06     2395.830322      2411.451660
# 2021-06-11  4.681671e+06  4.659835e+06     2404.822266      2420.020020
# 2021-06-12           NaN           NaN             NaN              NaN
# 2021-06-13           NaN           NaN             NaN              NaN
# 2021-06-14           NaN           NaN             NaN              NaN
# 2021-06-15           NaN           NaN             NaN              NaN
# 2021-06-16           NaN           NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# #**THANKYOU**
